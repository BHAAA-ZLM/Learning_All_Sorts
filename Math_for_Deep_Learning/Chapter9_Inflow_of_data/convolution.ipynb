# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.signal import convolve2d
from scipy.misc import face
from PIL import Image

# %%
img = face(True)
img = img[:512, (img.shape[1] - 612):(img.shape[1] - 100)]

# %%
k = np.array([[1,0,0], [0, -8, 0], [0,0,3]])
c = convolve2d(img, k, mode='same')

# %%
#show the image from the img matrix
plt.imshow(img, cmap='gray')
plt.show()

# %%
#show the image from the c matrix
plt.imshow(c, cmap='gray')
plt.show()

# %%
c[0:6, 0:6]
# Out:
# array([[-634, -676, -765, -890, -840, -724],
#        [-450, -209, -382, -566, -511, -278],
#        [-283, -106, -379, -571, -638, -438],
#        [-277, -168, -391, -484, -673, -568],
#        [-391, -278, -357, -332, -493, -341],
#        [-505, -335, -304, -216, -265, -168]])
